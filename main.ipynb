# %%
from linked_deque import LinkedDeque
from ledger_entry import LedgerEntry 
from stock_ledger import StockLedger

class main():
    
    #### testing
    
    test_deck = LinkedDeque()
    test_deck.add_to_back("A")
    print(test_deck.get_front().data)

    pass

#When you print your Stock Ledger it should look like this, 
# with the numbers changing as the program executes, of course.

# ---- Stock Ledger ----
# AAPL: 45.0 (20 shares), 75.0 (20 shares) 
# MSFT: 95.0 (20 shares) 

# You will test your work by doing the following:

main_stock_ledger = StockLedger()

#     Buy 20 shares of AAPL at $45.
main_stock_ledger.buy("AAPL", 20, 45)

#     Buy 20 shares of AAPL at $75.
main_stock_ledger.buy("AAPL", 20, 75)
#     Buy 20 shares of MSFT at $95.
main_stock_ledger.buy("MSFT", 20, 95)
#     Display the ledger 
# print(main_stock_ledger.display_ledger())
print(main_stock_ledger.display_ledger())
#     Sell 30 shares of AAPL at $65
main_stock_ledger.sell("AAPL", 30, 65)
#     Display the ledger 
print(main_stock_ledger.display_ledger())
#     Sell 10 shares of AAPL at $65
main_stock_ledger.sell("AAPL", 10, 65)
#     Display the ledger 
print(main_stock_ledger.display_ledger())
#     Buy 100 shares of AAPL at $20
main_stock_ledger.buy("AAPL", 100, 20)
#     Buy 20 shares of AAPL at $24
main_stock_ledger.buy("AAPL", 20, 24)
#     Buy 200 shares of TSLA at $36
main_stock_ledger.buy("TSLA", 200, 36)
#     Display the ledger 
print(main_stock_ledger.display_ledger())
#     Sell 10 shares of AAPL at $65
main_stock_ledger.sell("AAPL", 10, 65)
#     Display the ledger 
print(main_stock_ledger.display_ledger())
#     Sell 150 shares of TSLA at $30
main_stock_ledger.sell("TSLA", 150, 30)
#     Display the ledger 
print(main_stock_ledger.display_ledger())
#     Buy 5 shares of MSFT at $60
main_stock_ledger.buy("MSFT", 5, 60)
#     Buy 5 shares of MSFT at $70
main_stock_ledger.buy("MSFT", 5, 70)
#     Display the ledger 
# 
print(main_stock_ledger.display_ledger())
#     Sell 4 shares of MSFT at $30
main_stock_ledger.sell("MSFT", 4, 30)
#     Display the ledger
print(main_stock_ledger.display_ledger())
#     Sell 2 shares of MSFT at $30
main_stock_ledger.sell("MSFT", 2, 30)
#     Display the ledger 
print(main_stock_ledger.display_ledger())

# After all of this is done, you should have your final ledger display like this:

# ---- Stock Ledger ----
# AAPL: 20.0 (90 shares), 24.0 (20 shares) 
# MSFT: 95.0 (14 shares), 60.0 (5 shares), 70.0 (5 shares) 
# TSLA: 36.0 (50 shares)  

print("done")
# Out:
# A
# AAPL 75 (20 shares), 45 (20 shares), MSFT 95 (20 shares),
# before checking
# AAPL 45 (10 shares), MSFT 95 (20 shares),
# before checking
# after checking but before poping  [<ledger_entry.LedgerEntry object at 0x0000023DABFF91C0>, <ledger_entry.LedgerEntry object at 0x0000023DABEA1D90>]
# after poping  [<ledger_entry.LedgerEntry object at 0x0000023DABEA1D90>]
# MSFT 95 (20 shares),
# MSFT 95 (20 shares), AAPL 24 (20 shares), 20 (100 shares), TSLA 36 (200 shares),
# before checking
# MSFT 95 (20 shares), AAPL 24 (10 shares), 20 (100 shares), TSLA 36 (200 shares),
# before checking
# MSFT 95 (20 shares), AAPL 24 (10 shares), 20 (100 shares), TSLA 36 (50 shares),
# MSFT 70 (5 shares), 60 (5 shares), 95 (20 shares), AAPL 24 (10 shares), 20 (100 shares), TSLA 36 (50 shares),
# before checking
# MSFT 70 (1 shares), 60 (5 shares), 95 (20 shares), AAPL 24 (10 shares), 20 (100 shares), TSLA 36 (50 shares),
# before checking
# ...
